# %%
from termcolor import colored as c 
import random as r 

words={'always':'at all times; regularly', 'amount':'the amount of something is how much of it there is; a quantity of something', 'anchor':'a heavy metal object at the end of a chain that you drop into the water from a boat in order to stop the boat moving', 'animal':'a creature that is not a bird, a fish, an insect', 'annual':'occurring or happening every year or once a year;yearly.','answer':'to say or write something back to somebody who has asked you something or written to you','anyone':'any person or people.', 'anyways':'used to add an extra point or reason) in any case', 'appeal':'to make a serious request for something you need or want very much','appear':'to seem',  'arctic':'connected with the region around the North Pole', 'around':'in or to various places or directions', 'arrest':'when the police arrest somebody, they take him/her prisoner in order to question him/her about a crime','arrive':'to reach the place to which you were travelling', 'artery':'one of the tubes which take blood from the heart to other parts of the body', 'artist':'somebody who produces art, especially paintings or drawings', 'asleep':'not awake; sleeping', 'aspect':'one of the qualities or parts of a situation, idea, problem, etc.', 'assert':'to say something clearly and firmly', 'assess':'to say something clearly and firmly', 'assign':'to give something to somebody for a particular purpose', 'assist':'to help', 'assume':'to accept or believe that something is true even though you have no proof; to expect something to be true', 'assure':'to promise somebody that something will certainly happen or be true, especially if he/she is worried', 'asthma':'a chronic (long-term) condition that affects the airways in the lungs.', 'atomic':'of or concerning an atom or atoms', 'attach':'to fasten or join something to something', 'attack':'trying to hurt or defeat somebody/something by using force', 'attain':'to succeed in getting or achieving something, especially after a lot of effort', 'attend':'to go to or be present at a place', 'august':'respected and impressive', 'author':'a person who writes a book, play, etc.', 'autumn':'the season of the year that comes between summer and winter', 'avenue':'a wide street, especially one with trees or tall buildings on each side','abroad':'In or to another country or countries', 'aboard':'On or onto a train, ship, aircraft or bus', 'absorb':'1. To take in and hold something (a liquid, heat, etc.). 2.To take something into the mind and understand it.', 'absurd':'Not at all logical or sensible; ridiculous', 'accent':'A particular way of pronouncing words that is connected with the country, area or social class that you come from','accept':'To agree to take something that somebody offers you', 'access':'1. A way of entering or reaching a place;2. To find information on a computer','accord':'An agreement, especially between countries', 'across':'From one side of something to the other', 'acting':'The performing art in which movement, gesture, and intonation are used to realize a fictional character for the stage, for motion pictures, or for television.','action':'Doing things, often for a particular purpose', 'active':'Involved in activity; lively', 'actual':'real; that happened','adhere':'To stick firmly to something', 'adjust':'to change something slightly, especially because it is not in the right position.','admire':'To respect or like somebody/something very much; to look at somebody/something with pleasure', 'advent':'The fact of somebody/something arriving', 'advice':'A suggestion about what someone should do.','advise':'To give (someone) a recommendation about what should be done', 'aerial':'1.From or in the air; 2.A long metal stick on a building, car, etc. that receives radio or television signals','affair':'An event or a situation', 'affect':'Make somebody/something change in a particular way; to influence somebody/something', 'afford':'To have enough money or time to be able to do something','afraid':'Having or showing fear; frightened', 'agency':'A business that provides a particular service', 'agenda':'A list of matters that need to be discussed or dealt with','albeit':'Although', 'allied':'(used about organizations, countries, etc.) having an agreement to work together and support each other', 'killed':'(Past tense of kill); to make somebody/something die', 'almost':'very nearly; not quite','absent':'Not present; not at a particular place or event.','allege':'To claim or assert something, typically without providing proof.','ambush':'A surprise attack, typically one that is planned and concealed, often used in a military context.','archer':'A person who uses a bow and arrow, typically in sports, hunting, or warfare.','affirm':'To state something positively or to assert that it is true; to confirm or validate something.','annoys':'To irritate or disturb someone; to cause slight anger or frustration.','alarms':'Devices or sounds that warn of danger, or the act of causing someone to feel a sense of fear or concern.','arises':'To emerge, come into being, or appear; to originate or result from something.','adjust':'To alter or move something slightly to achieve a desired fit, condition, or result.','abduct':'To take someone away illegally by force or threat; to kidnap.','keeper':'A person who guards or looks after something', 'karate':'A style of fighting originally from Japan in which the hands and feet are used as weapons','kissed':'To touch somebody with your lips to show love', 'keypad':'A block or pad of buttons set with an arrangement of digits, symbols, or alphabetical letters.','kennel':'A small house for a dog','kicker':'A person or animal that kicks. OR; (informal) an unexpected and unwelcome discovery or turn of events.','kimono':'A traditional Japanese piece of clothing like a long dress with wide sleeves, worn on formal occasions.','katana':'A long, single-edged sword used by Japanese samurai.','kidnap':'To take somebody away by force and demand money for his/her safe return','khakis':'A light yellowish-brown cloth made usually of cotton or wool.','kayaks':'(plural of kayak) A light narrow boat (a canoe) for one person, that you move using with a stick with a flat part at each end (a paddle).','kiosks':'(plural of kiosk) A very small shop or stall in the street where newspapers, sweets, cigarettes, etc. are sold.','kindle':'1. To start a fire or to make something start to burn.  2. to start a fire or to make something start to burn.','kipper':'A type of fish that has been kept for a long time in salt, and then smoked.','knifes':'A sharp flat piece of metal (a blade) with a handle. A knife is used for cutting things or as a weapon.','kimchi':'A Korean side dish, made of fermented vegetable, generally cabbage.','kicked':'Past tense of "kick"; To strike something with the foot, typically with force.', 'kidney':'A pair of organs in the body that filter waste from the blood and produce urine.', 'knight':'A person granted a title of honor, often in medieval times, who serves a king or lord in exchange for land or protection.', 'kettle':'A container, typically made of metal, used for boiling water or cooking.', 'kindly':'In a friendly or considerate manner; showing kindness or compassion.', 'kilter':'A state of balance or proper functioning (often used in the phrase "out of kilter" meaning something is out of balance).', 'kisses':'Plural of "kiss": A gesture of affection, typically involving pressing the lips against someone or something.', 'knotty':'Full of knots; difficult or complex, often used to describe a problem or situation that is challenging to untangle.','killer':'A person or thing that kills or causes death. It can also refer to something that is exceptionally impressive or effective.','kitten':'A young cat, typically under one year of age.', 'kneels': "This is a verb that means to go down on one's knees, typically as a sign of respect or in prayer."}

print('Welcome!')
print("Guess a six letter word beginning with either 'A', or 'K'")
print()
print('If a letter is in the right position, then the letter will turn blue')
print('If it is in the correct word but not in the right position, it will turn pink')
print('If it is not in the correct word, it will turn grey')
print()
print('You will get six guesses to get to the correct word. Enjoy!:)')
print()

words0=list(words.keys())

def right_position(x, y):      #x: the letter, y:the color to turn letter in case of the condition being met
    b=c(x, y, attrs=['bold'])
    print(b, end=' ')
    
def in_word(x, y):
    m=c(x, y, )
    print(m, end=' ')

def not_in_word(x, y):
    g=c(x, y, attrs=['bold'])
    print(g, end=' ')

play_again='Go'
while play_again=='Go':
    
    correct_word1=r.choice(words0)
    
    guesses=0
    while guesses<6:
        guess=input().lower()
        meaning=c(words[correct_word1], attrs=['bold'])
        if guess==correct_word1:
            guess=c(guess, 'blue', attrs=['bold'])
            print(guess)
            print('You have guessed correctly!')
            print("The meaning of the word is:")
            print(meaning)
            break
        
        elif guess not in words0:
            print('Sorry, the word you have entered is not valid. Please try again')
            
            
        else:
            guesses+=1
            
            correct_word=list(correct_word1)
            for i in range(6):
                
                
                if guess[i]==correct_word[i]:
                    right_position(guess[i], 'blue')
                    correct_word[i]=" "

                
                elif guess[i] in correct_word:
                    in_word(guess[i], 'green')
                    letter=guess[i]
                    for j in range(6):
                        if correct_word[j]==letter:
                            correct_word[j]=' '
                            break
                        
                
                else:
                    not_in_word(guess[i], 'grey')
            print()
                
    else:
        print()
        print('Sorry, you could not guess correctly')
        print()
        word_= c(correct_word1, 'magenta', attrs=['bold'])
        print('The correct word was', word_)
        
        print('The meaning of', word_, 'is:')
        print(meaning)
        print()
        print('Thank you for playing with us!')
    play_again=input('Do you want to play again? Say Go. To quit playing , say Quit').title()  
if play_again=='Quit':
    print('See you again later!')
# Out:
# Welcome!
# Guess a six letter word beginning with either 'A', or 'K'
#
# If a letter is in the right position, then the letter will turn blue
# If it is in the correct word but not in the right position, it will turn pink
# If it is not in the correct word, it will turn grey
#
# You will get six guesses to get to the correct word. Enjoy!:)
